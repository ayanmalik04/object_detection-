# %% [markdown]
# # **Object Detection Using YoloV5 Algorithm**

# %% [markdown]
# # **Clonning the Repository**

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %% [markdown]
# # **Installing the dependencies**

# %%
# !pip install -U -r requirements.txt

# %% [markdown]
# #**Connecting to google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Now detecting the Image with yolov5 weights**

# %%
# !python detect.py --source /content/drive/MyDrive/img2.jpg --weights yolov5s.pt --conf 0.4
# Out:
# ...
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/img2.jpg, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-129-g7d56d45 torch 1.10.0+cu111 CPU
#
# ...
# 100% 14.0M/14.0M [00:00<00:00, 94.9MB/s]
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/img2.jpg: 448x640 1 person, 1 dog, Done. (0.296s)
# Speed: 3.5ms pre-process, 296.5ms inference, 16.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# ## **Plotting the Image using Cv2 and Matplotlib**

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread("/content/yolov5/runs/detect/exp/img2.jpg")
height, width = image.shape[:2]
resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# !python detect.py --source /content/drive/MyDrive/img1.jpg --weights yolov5s.pt --conf 0.4
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/img1.jpg, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-129-g7d56d45 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/img1.jpg: 384x640 13 persons, 3 cars, 1 bus, 2 traffic lights, Done. (0.277s)
# Speed: 2.6ms pre-process, 277.3ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
image1 = cv2.imread("/content/yolov5/runs/detect/exp2/img1.jpg")
height, width = image.shape[:2]
resized_image1 = cv2.resize(image1,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")
plt.imshow(cv2.cvtColor(resized_image1, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # **Now detecting with the video for the video I have taken people Image**

# %%
# !python detect.py --source /content/drive/MyDrive/people.mp4 --weights yolov5s.pt --conf 0.4
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/people.mp4, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-129-g7d56d45 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# video 1/1 (1/780) /content/drive/MyDrive/people.mp4: 384x640 14 persons, Done. (0.263s)
# video 1/1 (2/780) /content/drive/MyDrive/people.mp4: 384x640 15 persons, 1 handbag, Done. (0.238s)
# video 1/1 (3/780) /content/drive/MyDrive/people.mp4: 384x640 15 persons, 1 handbag, Done. (0.244s)
# video 1/1 (4/780) /content/drive/MyDrive/people.mp4: 384x640 14 persons, 2 handbags, Done. (0.244s)
# ...
